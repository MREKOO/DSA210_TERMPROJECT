# %% [markdown]
# # Explotary Data Analysis of Hypothesis #1
#
# This notebook analyzes the time spent per move in online chess games and compares patterns across game types (e.g., blitz, bullet, rapid) and outcomes (win/loss). The script processes `.json` files containing game data, extracts move timing info from PGNs, and performs statistical tests.
#
# ---

# %% [markdown]
# ### Imports
# These libraries are necessary for data processing, visualization, and statistical analysis.

# %%
import json
import re
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %% [markdown]
# ### Flow of the Program
# For a more organized fashion, this python script consists of spesific functions to overcome spesific tasks.

# %% [markdown]
# ### Function: `extract_time_data`
# This function is responsible for extract time data. Below is the implementation:

# %%
def extract_time_data(pgn_str):
    """Extract move numbers and time spent for each move from PGN string."""
    # Regular expression to match move numbers and clock times
    time_pattern = r'(\d+)\.\s+\{?\[%clk\s+(\d+):(\d+):(\d+\.?\d*)\]\}?'

    # Find all matches in the PGN string
    matches = re.findall(time_pattern, pgn_str)

    if not matches:
        # Try alternative pattern (some PGNs have different format)
        alt_pattern = r'(\d+)\.\s+[a-zA-Z0-9+#=]+\s+\{?\[%clk\s+(\d+):(\d+):(\d+\.?\d*)\]\}?'
        matches = re.findall(alt_pattern, pgn_str)

    move_times = []
    prev_time = None

    for match in matches:
        move_num = int(match[0])
        hours = int(match[1])
        minutes = int(match[2])
        seconds = float(match[3])

        # Convert to total seconds
        total_seconds = hours * 3600 + minutes * 60 + seconds

        if prev_time is not None:
            # Time spent on this move is the difference between previous time and current time
            time_spent = prev_time - total_seconds
            if time_spent > 0:  # Ensure not to get negative times
                move_times.append((move_num, time_spent))

        prev_time = total_seconds

    return move_times

# %% [markdown]
# ### Function: `parse_json_file`
# This function is responsible for parse json file. Below is the implementation:

# %%
def parse_json_file(file_path):
    """Parse a JSON file and return game data."""
    try:
        with open(file_path, 'r') as f:
            data = json.load(f)

        games = data.get('games', [])
        print(f"  - Found {len(games)} games in the file")

        # Check the first game structure if available
        if games and len(games) > 0:
            first_game = games[0]
            has_pgn = 'pgn' in first_game
            has_time_control = 'time_control' in first_game
            print(f"  - First game has pgn: {has_pgn}, has time_control: {has_time_control}")

            # Debug: Print more fields from the first game to understand structure
            print(f"  - Available fields in first game: {list(first_game.keys())}")
            if 'white' in first_game:
                print(f"  - White player: {first_game['white']}")
            if 'black' in first_game:
                print(f"  - Black player: {first_game['black']}")
            if 'end_time' in first_game:
                print(f"  - End time: {first_game['end_time']}")

            # Sample the PGN if available
            if has_pgn:
                pgn_sample = first_game['pgn'][:100] + "..." if len(first_game['pgn']) > 100 else first_game['pgn']
                print(f"  - PGN sample: {pgn_sample}")

        return games

    except FileNotFoundError:
        print(f"  - File not found: {file_path}")
        return []
    except json.JSONDecodeError:
        print(f"  - Error parsing JSON in file: {file_path}")
        return []
    except Exception as e:
        print(f"  - Unexpected error: {str(e)}")
        return []

# %% [markdown]
# ### Function: `categorize_game`
# This function is responsible for categorize game. Below is the implementation:

# %%
def categorize_game(time_control):
    """Categorize a game based on its time control."""
    if not time_control:
        return "unknown"

    # For daily games or games with days (e.g., "1/604800")
    if isinstance(time_control, str) and time_control.startswith("1/") and int(time_control.split('/')[1]) >= 86400:
        return "daily"

    # Extract the base time in seconds
    try:
        base_time = int(time_control.split('+')[0]) if isinstance(time_control, str) and '+' in time_control else int(time_control)
    except (ValueError, TypeError):
        return "unknown"

    if base_time < 180:  # Less than 3 minutes
        return "bullet"
    elif base_time < 600:  # Less than 10 minutes
        return "blitz"
    else:
        return "rapid"

# %% [markdown]
# ### Function: `determine_game_result`
# This function is responsible for determine game result. Below is the implementation:

# %%
def determine_game_result(game):
    """Determine if mreko0 won or lost the game."""
    # We are analyzing in the scope of my game results only.
    MY_USERNAME = "MrEKO0"

    # Debug the game structure
    if 'white' in game:
        white_player = game['white']
        print(f"  - White player: {white_player}")
    if 'black' in game:
        black_player = game['black']
        print(f"  - Black player: {black_player}")

    # First check if I am white or black in the spesific game.
    your_color = None
    opponent_color = None

    # Method 1: Check for direct string username
    if 'white' in game and game['white'] == MY_USERNAME:
        your_color = 'white'
        opponent_color = 'black'
    elif 'black' in game and game['black'] == MY_USERNAME:
        your_color = 'black'
        opponent_color = 'white'
    # Method 2: Check for dictionary with username
    elif 'white' in game and isinstance(game['white'], dict) and game['white'].get('username') == MY_USERNAME:
        your_color = 'white'
        opponent_color = 'black'
    elif 'black' in game and isinstance(game['black'], dict) and game['black'].get('username') == MY_USERNAME:
        your_color = 'black'
        opponent_color = 'white'

    if not your_color:
        print(f"  - Could not find {MY_USERNAME} as white or black player")
        return 'other'

    print(f"  - Found {MY_USERNAME} as {your_color} player")

    # Look for game ending condition
    if 'end_time' in game:
        print(f"  - Game ended at: {game['end_time']}")

    # Method 1: Check for an explicit user win field
    if your_color + '_result' in game:
        result = game[your_color + '_result'].lower()
        print(f"  - {your_color}_result field: {result}")
        if result == 'win':
            return 'win'
        else:
            return 'loss'

    # Method 2: Check for explicit end reason
    end_reason_fields = ['state', 'status', 'end_reason', 'termination']
    for field in end_reason_fields:
        if field in game:
            end_reason = str(game[field]).lower()
            print(f"  - {field}: {end_reason}")

            # Win conditions
            if end_reason in ['win', 'mate', 'checkmate'] and 'winner' in game and game['winner'] == your_color:
                return 'win'
            if opponent_color + '_checkmated' in end_reason or opponent_color + '_resigned' in end_reason:
                return 'win'
            if your_color + '_won' in end_reason or your_color + '_wins' in end_reason:
                return 'win'

            # Loss conditions
            if end_reason in ['checkmated', 'resigned', 'timeout', 'abandoned']:
                if 'winner' in game and game['winner'] == opponent_color:
                    return 'loss'
                # If no winner field but these usually mean loss
                return 'loss'
            if your_color + '_checkmated' in end_reason or your_color + '_resigned' in end_reason:
                return 'loss'
            if your_color + '_lost' in end_reason:
                return 'loss'

    # Method 3: Check for direct winner field
    if 'winner' in game:
        winner = str(game['winner']).lower()
        print(f"  - Winner field: {winner}")
        if winner == your_color:
            return 'win'
        elif winner == opponent_color:
            return 'loss'
        elif winner == MY_USERNAME.lower():
            return 'win'

    # Method 4: Check PGN for result
    pgn = game.get('pgn', '')
    if f'[White "{MY_USERNAME}"]' in pgn and '[Result "1-0"]' in pgn:
        return 'win'
    elif f'[Black "{MY_USERNAME}"]' in pgn and '[Result "0-1"]' in pgn:
        return 'win'
    elif f'[White "{MY_USERNAME}"]' in pgn and '[Result "0-1"]' in pgn:
        return 'loss'
    elif f'[Black "{MY_USERNAME}"]' in pgn and '[Result "1-0"]' in pgn:
        return 'loss'

    # Method 5: For Chess.com format, specifically check for a result field
    if 'white' in game and isinstance(game['white'], dict) and 'result' in game['white']:
        white_result = game['white']['result'].lower()
        if your_color == 'white':
            if white_result == 'win':
                return 'win'
            else:
                return 'loss'
        else:  # Black
            if white_result == 'win':
                return 'loss'
            else:
                return 'win'

    if 'black' in game and isinstance(game['black'], dict) and 'result' in game['black']:
        black_result = game['black']['result'].lower()
        if your_color == 'black':
            if black_result == 'win':
                return 'win'
            else:
                return 'loss'
        else:  # White
            if black_result == 'win':
                return 'loss'
            else:
                return 'win'

    # If we still cannot determine, look at game details one last time
    if 'details' in game and isinstance(game['details'], str):
        details = game['details'].lower()
        print(f"  - Game details: {details}")
        if f"{MY_USERNAME.lower()} won" in details:
            return 'win'
        elif "timeout" in details and your_color in details:
            return 'loss'
        elif "resigned" in details and your_color in details:
            return 'loss'

    # If we cannot determine or the game was a draw
    print("  - Could not determine game result, marking as 'other'")
    return 'other'  # 'other' includes draws and indeterminate results

# %% [markdown]
# ### Function: `main`
# This is where we define the main function. It checks for available JSON files, processes each game, and generates visualizations and  if enabled, statistical reports.

# %%
def main(json_files):
    # Initialize containers for move times categorized by game type and result
    results = {
        'all': {'win': [], 'loss': []},
        'blitz': {'win': [], 'loss': []},
        'bullet': {'win': [], 'loss': []},
        'rapid': {'win': [], 'loss': []},
        'daily': {'win': [], 'loss': []},
    }

    total_games_with_data = 0
    games_won = 0
    games_lost = 0
    games_other = 0

    # Process each JSON file
    for file_name in json_files:
        if os.path.exists(file_name):
            print(f"Processing file: {file_name}")
            games = parse_json_file(file_name)

            games_with_data_in_file = 0
            file_wins = 0
            file_losses = 0
            file_other = 0

            for i, game in enumerate(games):
                if i < 3:  # Debug first 3 games
                    print(f"\nExamining game {i+1}:")

                pgn = game.get('pgn', '')
                time_control = game.get('time_control', '')

                # Skip games without PGN or time control
                if not pgn or not time_control:
                    if i < 3:
                        print(f"  - Skipping game {i+1}: Missing PGN or time control")
                    continue

                # Extract move times
                move_times = extract_time_data(pgn)

                if move_times:
                    games_with_data_in_file += 1

                    # Determine game result
                    result = determine_game_result(game)

                    if i < 3:  # Debug first 3 games
                        print(f"  - Game {i+1} result: {result}")

                    if result == 'win':
                        games_won += 1
                        file_wins += 1
                    elif result == 'loss':
                        games_lost += 1
                        file_losses += 1
                    else:
                        games_other += 1
                        file_other += 1
                        continue  # Skip draws and indeterminate games

                    # Categorize by game type
                    game_type = categorize_game(time_control)

                    # Add to appropriate lists
                    if result in ['win', 'loss']:
                        results['all'][result].extend(move_times)

                        if game_type in ['blitz', 'bullet', 'rapid', 'daily']:
                            results[game_type][result].extend(move_times)

            print(f"  - Extracted timing data from {games_with_data_in_file} games")
            print(f"  - In this file: Wins: {file_wins}, Losses: {file_losses}, Other: {file_other}")
            total_games_with_data += games_with_data_in_file

        else:
            print(f"File not found: {file_name}")

    # Print statistics
    print("\nSUMMARY:")
    print(f"Total games with timing data: {total_games_with_data}")
    print(f"Games won: {games_won}")
    print(f"Games lost: {games_lost}")
    print(f"Games drawn/indeterminate: {games_other}")

    print("\nMove data points:")
    for category in results:
        for result in ['win', 'loss']:
            move_count = len(results[category][result])
            print(f"  - {category.capitalize()} games - {result}: {move_count} moves")

    # Generate plots for each category and result
    for category in results:
        for result in ['win', 'loss']:
            move_times = results[category][result]
            if move_times:
                title = f"{category.capitalize()} Games - {result.capitalize()}"
                filename = f"{category}_{result}.png"
                plot_move_times(move_times, title, filename)
                print(f"Generated plot for {title} with {len(move_times)} move data points")
            else:
                print(f"No move time data found for {category} games - {result}")

    # Create combined plots for direct comparison
    create_combined_plots(results)

    create_additional_plots(results)

    # perform_hypothesis_tests(results) Uncomment to use the function when defined.

# %% [markdown]
# ### Function: `create_combined_plots`
# This function is responsible for create combined plots. Below is the implementation:

# %%
def create_combined_plots(results):
    """Create separate plots for wins and losses for each category."""
    categories = ['all', 'blitz', 'bullet', 'rapid', 'daily']

    for category in categories:
        win_data = results[category]['win']
        loss_data = results[category]['loss']

        # Create separate plot for wins
        if win_data:
            plt.figure(figsize=(14, 10))
            win_moves = [mt[0] for mt in win_data]
            win_times = [mt[1] for mt in win_data]
            plt.scatter(win_moves, win_times, alpha=0.5, color='green', label='Wins', s=30)

            # Add trendline for wins
            z_win = np.polyfit(win_moves, win_times, 1)
            p_win = np.poly1d(z_win)
            plt.plot(sorted(win_moves), p_win(sorted(win_moves)), "g--", alpha=0.7)

            # Calculate and display average time per move for wins
            avg_win_time = sum(win_times) / len(win_times)
            plt.annotate(f'Avg time: {avg_win_time:.2f}s',
                         xy=(0.05, 0.95), xycoords='axes fraction',
                         fontsize=12, color='green')

            # Add labels and title
            plt.xlabel('Move Number')
            plt.ylabel('Time Spent (seconds)')
            plt.title(f'Time Spent per Move - {category.capitalize()} Games (Wins)')

            plt.legend()
            plt.grid(True, alpha=0.3)

            # Set axis limits for better visualization
            plt.ylim(0, min(max(win_times) * 1.1, 120))  # Cap at 120 seconds for readability

            # Save the plot
            filename = f"{category}_wins.png"
            plt.savefig(filename)
            plt.close()
            print(f"Wins plot saved as {filename}")

        # Create separate plot for losses
        if loss_data:
            plt.figure(figsize=(14, 10))
            loss_moves = [mt[0] for mt in loss_data]
            loss_times = [mt[1] for mt in loss_data]
            plt.scatter(loss_moves, loss_times, alpha=0.5, color='red', label='Losses', s=30)

            # Add trendline for losses
            z_loss = np.polyfit(loss_moves, loss_times, 1)
            p_loss = np.poly1d(z_loss)
            plt.plot(sorted(loss_moves), p_loss(sorted(loss_moves)), "r--", alpha=0.7)

            # Calculate and display average time per move for losses
            avg_loss_time = sum(loss_times) / len(loss_times)
            plt.annotate(f'Avg time: {avg_loss_time:.2f}s',
                         xy=(0.05, 0.95), xycoords='axes fraction',
                         fontsize=12, color='red')

            # Add labels and title
            plt.xlabel('Move Number')
            plt.ylabel('Time Spent (seconds)')
            plt.title(f'Time Spent per Move - {category.capitalize()} Games (Losses)')

            plt.legend()
            plt.grid(True, alpha=0.3)

            # Set axis limits for better visualization
            plt.ylim(0, min(max(loss_times) * 1.1, 120))  # Cap at 120 seconds for readability

            # Save the plot
            filename = f"{category}_losses.png"
            plt.savefig(filename)
            plt.close()
            print(f"Losses plot saved as {filename}")

# %% [markdown]
# ### Function: `plot_move_times`
# This function is responsible for plot move times. Below is the implementation:

# %%
def plot_move_times(move_times, title, filename):
    """Create a scatter plot of move times."""
    if not move_times:
        print(f"No data for {title}")
        return

    move_numbers = [mt[0] for mt in move_times]
    times_spent = [mt[1] for mt in move_times]

    plt.figure(figsize=(12, 8))

    # Create scatter plot
    plt.scatter(move_numbers, times_spent, alpha=0.5, s=30)

    # Add trendline
    z = np.polyfit(move_numbers, times_spent, 1)
    p = np.poly1d(z)
    plt.plot(move_numbers, p(move_numbers), "r--", alpha=0.7)

    # Add labels and title
    plt.xlabel('Move Number')
    plt.ylabel('Time Spent (seconds)')
    plt.title(f'Time Spent per Move - {title}')

    # Add average time per move
    avg_time = sum(times_spent) / len(times_spent)
    plt.axhline(avg_time, color='blue', linestyle='--', alpha=0.7)
    plt.annotate(f'Average: {avg_time:.2f}s',
                xy=(0.05, 0.95), xycoords='axes fraction',
                fontsize=12, color='blue')

    # Add grid
    plt.grid(True, alpha=0.3)

    # Set axis limits for better visualization
    plt.ylim(0, min(max(times_spent) * 1.1, 120))  # Cap at 120 seconds for readability

    # Save the plot
    plt.savefig(filename)
    plt.close()
    print(f"Plot saved as {filename}")

# %% [markdown]
# ### Function: `create_additional_plots`
# This function is responsible for create additional plots. Below is the implementation:

# %%
def create_additional_plots(results):
    """Create additional plots (heatmap, violin, histogram, box plot) for each category and result."""
    categories = ['all', 'blitz', 'bullet', 'rapid', 'daily']
    results_types = ['win', 'loss']

    for category in categories:
        # Skip if either wins or losses are empty
        if not results[category]['win'] or not results[category]['loss']:
            print(f"Skipping additional plots for {category} - insufficient data")
            continue

        # Extract move numbers and times
        win_moves = [mt[0] for mt in results[category]['win']]
        win_times = [mt[1] for mt in results[category]['win']]
        loss_moves = [mt[0] for mt in results[category]['loss']]
        loss_times = [mt[1] for mt in results[category]['loss']]

        # 1. Create histograms of time spent
        plt.figure(figsize=(14, 8))
        bins = np.linspace(0, min(max(max(win_times), max(loss_times)) * 1.1, 120), 30)
        plt.hist(win_times, bins=bins, alpha=0.5, color='green', label='Wins')
        plt.hist(loss_times, bins=bins, alpha=0.5, color='red', label='Losses')
        plt.xlabel('Time Spent (seconds)')
        plt.ylabel('Frequency')
        plt.title(f'Distribution of Time Spent per Move - {category.capitalize()} Games')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.savefig(f"{category}_time_histogram.png")
        plt.close()
        print(f"Histogram saved as {category}_time_histogram.png")

        # 2. Create box plots for time comparison
        plt.figure(figsize=(10, 8))
        box_data = [win_times, loss_times]
        plt.boxplot(box_data, labels=['Wins', 'Losses'], patch_artist=True,
                   boxprops=dict(facecolor='lightblue', color='blue'),
                   whiskerprops=dict(color='blue'),
                   capprops=dict(color='blue'),
                   medianprops=dict(color='red'))
        plt.ylabel('Time Spent (seconds)')
        plt.title(f'Box Plot of Time Spent per Move - {category.capitalize()} Games')
        plt.grid(True, alpha=0.3)
        plt.ylim(0, min(np.percentile(win_times + loss_times, 95) * 1.2, 120))  # Cap at 120 seconds but show 95th percentile
        plt.savefig(f"{category}_time_boxplot.png")
        plt.close()
        print(f"Box plot saved as {category}_time_boxplot.png")

        # 3. Create violin plots
        plt.figure(figsize=(10, 8))
        positions = [1, 2]
        violin_parts = plt.violinplot([win_times, loss_times], positions, showmeans=True, showmedians=True)
        # Customize violin appearance
        for pc in violin_parts['bodies']:
            pc.set_facecolor('lightblue')
            pc.set_alpha(0.7)
        violin_parts['cmeans'].set_color('red')
        violin_parts['cmedians'].set_color('black')
        plt.xticks(positions, ['Wins', 'Losses'])
        plt.ylabel('Time Spent (seconds)')
        plt.title(f'Violin Plot of Time Spent per Move - {category.capitalize()} Games')
        plt.grid(True, alpha=0.3)
        plt.ylim(0, min(np.percentile(win_times + loss_times, 95) * 1.2, 120))
        plt.savefig(f"{category}_time_violin.png")
        plt.close()
        print(f"Violin plot saved as {category}_time_violin.png")

        # 4. Create heatmap of move number vs time spent
        # Group data by move number
        max_move = max(max(win_moves), max(loss_moves))

        # Initialize arrays for the heatmaps
        win_move_times = [[] for _ in range(max_move + 1)]
        loss_move_times = [[] for _ in range(max_move + 1)]

        # Group times by move number
        for move, time in results[category]['win']:
            if move <= max_move:
                win_move_times[move].append(time)

        for move, time in results[category]['loss']:
            if move <= max_move:
                loss_move_times[move].append(time)

        # Calculate average time per move (avoiding division by zero)
        win_avg_times = [np.mean(times) if times else 0 for times in win_move_times]
        loss_avg_times = [np.mean(times) if times else 0 for times in loss_move_times]

        # Create heatmap for wins
        plt.figure(figsize=(14, 6))
        plt.subplot(1, 2, 1)
        # Only include moves with data
        valid_moves = [i for i, times in enumerate(win_move_times) if times]
        if valid_moves:
            plt.bar(valid_moves, [win_avg_times[m] for m in valid_moves], color='green', alpha=0.7)
            plt.xlabel('Move Number')
            plt.ylabel('Average Time (seconds)')
            plt.title(f'Avg Time per Move - {category.capitalize()} Wins')
            plt.grid(True, alpha=0.3)
            plt.ylim(0, min(max([win_avg_times[m] for m in valid_moves if win_avg_times[m]]) * 1.2, 120))

        # Create heatmap for losses
        plt.subplot(1, 2, 2)
        valid_moves = [i for i, times in enumerate(loss_move_times) if times]
        if valid_moves:
            plt.bar(valid_moves, [loss_avg_times[m] for m in valid_moves], color='red', alpha=0.7)
            plt.xlabel('Move Number')
            plt.ylabel('Average Time (seconds)')
            plt.title(f'Avg Time per Move - {category.capitalize()} Losses')
            plt.grid(True, alpha=0.3)
            plt.ylim(0, min(max([loss_avg_times[m] for m in valid_moves if loss_avg_times[m]]) * 1.2, 120))

        plt.tight_layout()
        plt.savefig(f"{category}_move_heatmap.png")
        plt.close()
        print(f"Heatmap saved as {category}_move_heatmap.png")

# %% [markdown]
# ### Main Execution Block
# This is where the script begins execution. It checks for available JSON files, processes each game, and generates visualizations and statistical reports if it is enabled in the main function definition.

# %%
if __name__ == '__main__': # To be able to import functions if needed.

    # List of JSON files to process
    json_files = [
        "2023-02.json", "2023-03.json", "2023-04.json", "2023-05.json",
        "2023-06.json", "2023-07.json", "2023-08.json", "2023-09.json",
        "2023-10.json", "2023-11.json", "2023-12.json",
        "2024-01.json", "2024-02.json", "2024-03.json", "2024-04.json",
        "2024-05.json", "2024-06.json", "2024-07.json", "2024-08.json",
        "2024-09.json", "2024-10.json", "2024-11.json", "2024-12.json",
        "2025-01.json", "2025-02.json", "2025-03.json", "2025-04.json"
    ]

    # Check if at least one JSON file exists
    existing_files = [f for f in json_files if os.path.exists(f)]
    if not existing_files:
        print("None of the specified JSON files found. Exiting.")
    else:
        main(json_files)
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#   - White player: {'rating': 908, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 907, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/ariasarias924', 'username': 'ariasarias924', 'uuid': 'b591376c-38d1-11eb-ad3d-b71d6ef5c1c4'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687290481
#   - White player: {'rating': 880, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/edoggy25', 'username': 'edoggy25', 'uuid': '86864666-8aab-11eb-9d97-7bdd081acdc8'}
#   - Black player: {'rating': 916, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687290612
#   - White player: {'rating': 926, 'result': 'win', '@id': 'https://api.chess.com/pub/player/arthur_thi', 'username': 'Arthur_thi', 'uuid': '23465c9a-6eda-11eb-a691-eb7a0f72d7f0'}
#   - Black player: {'rating': 908, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687290736
#   - White player: {'rating': 892, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mrdigsus', 'username': 'mrdigsus', 'uuid': '82f57c1e-2e27-11dc-803b-000000000000'}
#   - Black player: {'rating': 916, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687290890
#   - White player: {'rating': 925, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 957, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/lukbrucc', 'username': 'LukBrucc', 'uuid': '08cd7778-4cf5-11ec-ae6a-ef76ce097b75'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687337709
#   - White player: {'rating': 934, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 977, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/ferdinandfleck', 'username': 'FerdinandFleck', 'uuid': 'e0ab25a0-a960-11ed-8239-85a470245711'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687338287
#   - White player: {'rating': 941, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/alprazolam2137', 'username': 'alprazolam2137', 'uuid': '6773df46-5bc5-11eb-a4b8-9da63a9162e3'}
#   - Black player: {'rating': 942, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687340173
#   - White player: {'rating': 935, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 982, 'result': 'win', '@id': 'https://api.chess.com/pub/player/amaansc', 'username': 'AmaanSC', 'uuid': 'bbe41a78-c2f2-11ed-a1d6-1fb7c34a9571'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687340306
#   - White player: {'rating': 927, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 963, 'result': 'win', '@id': 'https://api.chess.com/pub/player/amzone', 'username': 'AmZONE', 'uuid': '3a66000e-9973-11e8-8016-000000000000'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687340454
#   - White player: {'rating': 936, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 956, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/hvishwa', 'username': 'HVishwa', 'uuid': '98b24be2-dd6c-11e5-8030-000000000000'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687340870
#   - White player: {'rating': 932, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/konggulerod', 'username': 'konggulerod', 'uuid': 'eabccc00-b92c-11e5-8000-000000000000'}
#   - Black player: {'rating': 944, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687341168
#   - White player: {'rating': 921, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/katzyj', 'username': 'katzyj', 'uuid': 'e02be0be-0ba2-11eb-b3a9-991681a1e10b'}
#   - Black player: {'rating': 952, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687341316
#   - White player: {'rating': 945, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 985, 'result': 'win', '@id': 'https://api.chess.com/pub/player/karthick1616', 'username': 'karthick1616', 'uuid': 'acb55214-8dce-11e3-801c-000000000000'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687341427
#   - White player: {'rating': 963, 'result': 'stalemate', '@id': 'https://api.chess.com/pub/player/regioj', 'username': 'regioj', 'uuid': 'd5df0774-78b7-11de-8027-000000000000'}
#   - Black player: {'rating': 945, 'result': 'stalemate', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687341576
#   - White player: {'rating': 966, 'result': 'win', '@id': 'https://api.chess.com/pub/player/jayjayhihi', 'username': 'jayjayhihi', 'uuid': 'a7f6472c-b9c7-11ed-96ca-0b302d8d2539'}
#   - Black player: {'rating': 937, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687343348
#   - White player: {'rating': 928, 'result': 'abandoned', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 916, 'result': 'win', '@id': 'https://api.chess.com/pub/player/barthenken', 'username': 'BartHenken', 'uuid': 'dd410d50-d1e7-11eb-a51e-2fbc98b2af07'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687343405
#   - White player: {'rating': 928, 'result': 'repetition', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 927, 'result': 'repetition', '@id': 'https://api.chess.com/pub/player/skyagunsta', 'username': 'Skyagunsta', 'uuid': '6e57400e-bf25-11e7-800a-000000000000'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687343518
#   - White player: {'rating': 913, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/majorhyperbole', 'username': 'MajorHyperbole', 'uuid': '37357cfa-9c8e-11ea-9e23-25605a693ff2'}
#   - Black player: {'rating': 936, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687343653
#   - White player: {'rating': 945, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 964, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/vishvaraj77', 'username': 'vishvaraj77', 'uuid': 'd3032858-c31c-11ea-8aa6-9fd64ae46be7'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687343735
#   - White player: {'rating': 968, 'result': 'win', '@id': 'https://api.chess.com/pub/player/sorobai', 'username': 'Sorobai', 'uuid': '4dffcb44-6cd3-11de-8025-000000000000'}
#   - Black player: {'rating': 937, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687343857
#   - White player: {'rating': 928, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 921, 'result': 'win', '@id': 'https://api.chess.com/pub/player/minglagay', 'username': 'Minglagay', 'uuid': 'dbbbfe5e-73fd-11ed-b384-cf70bb896566'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687343996
#   - White player: {'rating': 921, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 973, 'result': 'win', '@id': 'https://api.chess.com/pub/player/gullbrand', 'username': 'gullbrand', 'uuid': '6e285518-f1e1-11e5-8030-000000000000'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687344155
#   - White player: {'rating': 951, 'result': 'win', '@id': 'https://api.chess.com/pub/player/overlorddaniel', 'username': 'OverlordDaniel', 'uuid': '4e73b9a8-a8f9-11ec-bb89-3346c917e455'}
#   - Black player: {'rating': 914, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687344285
#   - White player: {'rating': 893, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/olsi15', 'username': 'Olsi15', 'uuid': '82f56146-002d-11ed-9bae-559d89fdd158'}
#   - Black player: {'rating': 922, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687344410
#   - White player: {'rating': 929, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 879, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/dzhey07', 'username': 'dzhey07', 'uuid': '96c8f3a6-0773-11ee-97fb-a79bd5601b8e'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687344552
#   - White player: {'rating': 940, 'result': 'win', '@id': 'https://api.chess.com/pub/player/goldsilvergold', 'username': 'goldsilvergold', 'uuid': '63080348-02e3-11ee-bcf9-6976295acc3b'}
#   - Black player: {'rating': 921, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687344697
#   - White player: {'rating': 880, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/uygartandoan3092', 'username': 'Uygartandoan3092', 'uuid': '726b0bc2-1582-11e8-8038-000000000000'}
#   - Black player: {'rating': 1252, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687505469
#   - White player: {'rating': 937, 'result': 'win', '@id': 'https://api.chess.com/pub/player/soldierlyzeus1', 'username': 'SoldierlyZeus1', 'uuid': 'b74b3fba-7082-11eb-90ef-5b25310c80b3'}
#   - Black player: {'rating': 913, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687539752
#   - White player: {'rating': 920, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 869, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/u031980', 'username': 'u031980', 'uuid': '3175b17a-40c4-11ea-aaf5-f5395794dd46'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687539891
#   - White player: {'rating': 911, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 885, 'result': 'win', '@id': 'https://api.chess.com/pub/player/eltunas25', 'username': 'eltunas25', 'uuid': '4420360c-abcd-11ed-9b17-d5d022551cb1'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687540041
#   - White player: {'rating': 903, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 919, 'result': 'win', '@id': 'https://api.chess.com/pub/player/olek_dk', 'username': 'Olek_dk', 'uuid': 'cb894dde-564a-11eb-b155-edf691d7d815'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687540175
#   - White player: {'rating': 907, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mario260674', 'username': 'Mario260674', 'uuid': '696ed10c-dbc4-11e9-acd3-835eb403aec4'}
#   - Black player: {'rating': 911, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687540302
#   - White player: {'rating': 902, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 900, 'result': 'win', '@id': 'https://api.chess.com/pub/player/naissem26', 'username': 'naissem26', 'uuid': 'c67d9762-73eb-11ed-846f-a9779983e5bc'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687634248
#   - White player: {'rating': 895, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 958, 'result': 'win', '@id': 'https://api.chess.com/pub/player/tbridger11', 'username': 'tbridger11', 'uuid': '77a00d3c-9bba-11ec-adca-135ca1951ecc'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687634389
#   - White player: {'rating': 861, 'result': 'win', '@id': 'https://api.chess.com/pub/player/josemichess', 'username': 'josemichess', 'uuid': '626ae702-9d04-11e2-8010-000000000000'}
#   - Black player: {'rating': 886, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687634544
#   - White player: {'rating': 874, 'result': 'win', '@id': 'https://api.chess.com/pub/player/tisertiser', 'username': 'tisertiser', 'uuid': '68be617a-a286-11eb-864e-8ddd31c1da34'}
#   - Black player: {'rating': 878, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687634686
#   - White player: {'rating': 933, 'result': 'win', '@id': 'https://api.chess.com/pub/player/x-9081549056', 'username': 'x-9081549056', 'uuid': '210e1840-dc5d-11ec-97dc-2fcca4bdb837'}
#   - Black player: {'rating': 871, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687634819
#   - White player: {'rating': 863, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 897, 'result': 'win', '@id': 'https://api.chess.com/pub/player/vkd009', 'username': 'vkd009', 'uuid': '5bd251cc-7403-11ea-9049-eda425e6f150'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687634959
#   - White player: {'rating': 891, 'result': 'win', '@id': 'https://api.chess.com/pub/player/jazzyball', 'username': 'JazzyBall', 'uuid': 'ab797df8-3c4c-11e9-bff7-13ad28a468ef'}
#   - Black player: {'rating': 855, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687635098
#   - White player: {'rating': 847, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 881, 'result': 'win', '@id': 'https://api.chess.com/pub/player/huissel', 'username': 'Huissel', 'uuid': '9b030e20-4252-11ed-a48f-c71375c6e7c2'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687635230
#   - White player: {'rating': 854, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 815, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/gatienlh', 'username': 'GatienLH', 'uuid': '2d696d2c-1821-11ea-9da4-bd67ab31c892'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687635379
#   - White player: {'rating': 843, 'result': 'win', '@id': 'https://api.chess.com/pub/player/flashbutton', 'username': 'FlashButton', 'uuid': 'a5526e80-5810-11eb-9895-159984f3eead'}
#   - Black player: {'rating': 846, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687635503
#   - White player: {'rating': 854, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 822, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/gian_lxco', 'username': 'gian_lxco', 'uuid': 'adaeebe4-0a2e-11ee-bdd4-71a78e1be547'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687770186
#   - White player: {'rating': 870, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/sentinel275', 'username': 'Sentinel275', 'uuid': 'd8fbab08-b804-11eb-91a3-0735d0af494e'}
#   - Black player: {'rating': 863, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687770279
#   - White player: {'rating': 855, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 856, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mammo123gg', 'username': 'mammo123gg', 'uuid': '0781f87c-9816-11ed-b042-e37d116d3da2'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687770407
#   - White player: {'rating': 863, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 853, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/xandaoemeupastor', 'username': 'xandaoemeupastor', 'uuid': '98365d80-ce59-11ed-a82d-d58e3040ce35'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687770552
#   - White player: {'rating': 880, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/zayyyyyyyyyyyyyyyy', 'username': 'zayyyyyyyyyyyyyyyy', 'uuid': 'b7a9698c-ab91-11ec-bee8-f34ff4de0cc0'}
#   - Black player: {'rating': 872, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687770759
#   - White player: {'rating': 901, 'result': 'win', '@id': 'https://api.chess.com/pub/player/compactpet', 'username': 'CompactPet', 'uuid': 'f70dce58-123e-11eb-8650-9f8976da77d8'}
#   - Black player: {'rating': 865, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687770833
#   - White player: {'rating': 859, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 967, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mukulaudi', 'username': 'mukulaudi', 'uuid': '57806066-b556-11ea-a231-d1b225b95ad2'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687770988
#   - White player: {'rating': 894, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/andr_souza', 'username': 'Andr_Souza', 'uuid': '47f11058-9a70-11ed-b600-05825bbdb5f2'}
#   - Black player: {'rating': 868, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687771142
#   - White player: {'rating': 868, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/rapstu', 'username': 'Rapstu', 'uuid': '7bef9482-8b0b-11ea-9a33-95883f222944'}
#   - Black player: {'rating': 876, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687771257
#   - White player: {'rating': 907, 'result': 'win', '@id': 'https://api.chess.com/pub/player/parehnamnnn', 'username': 'ParehNamnnn', 'uuid': 'f6a97fe4-c7e9-11ed-8e5f-47aacd6c47d6'}
#   - Black player: {'rating': 869, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687771406
#   - White player: {'rating': 877, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 844, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/kuntakintegambici', 'username': 'kuntakintegambici', 'uuid': '151bca0c-0665-11eb-816a-073391c3f537'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687771543
#   - White player: {'rating': 885, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 862, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/ikens', 'username': 'Ikens', 'uuid': 'ee0e8904-2766-11eb-a2c8-f9b5290103ef'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687771682
#   - White player: {'rating': 887, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/sceleste_1441', 'username': 'Sceleste_1441', 'uuid': '5dc4a0d4-7173-11eb-9988-a77828801b1e'}
#   - Black player: {'rating': 893, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687771823
#   - White player: {'rating': 848, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/frikandel35', 'username': 'Frikandel35', 'uuid': 'fa56df5c-3829-11ec-ace0-4946f264ba72'}
#   - Black player: {'rating': 900, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687772004
#   - White player: {'rating': 897, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 866, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/samisamibz', 'username': 'Samisamibz', 'uuid': 'ce0f32de-e45c-11ec-8c78-bf52bde7d62f'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687786382
#   - White player: {'rating': 905, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 906, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/srinivasan01', 'username': 'Srinivasan01', 'uuid': 'b9ee3dc4-1aa4-11ea-995d-1b986a28ca69'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687786941
#   - White player: {'rating': 914, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 938, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/vicentepz', 'username': 'vicentepz', 'uuid': 'dca78ede-3d7f-11eb-bded-ef7b65270cd6'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687787020
#   - White player: {'rating': 922, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 922, 'result': 'abandoned', '@id': 'https://api.chess.com/pub/player/cruizelogic', 'username': 'Cruizelogic', 'uuid': 'a4fb4474-664e-11eb-befe-5b2ec9d0ee91'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687787296
#   - White player: {'rating': 958, 'result': 'win', '@id': 'https://api.chess.com/pub/player/semiba', 'username': 'Semiba', 'uuid': '50edb764-ec2e-11e8-8024-000000000000'}
#   - Black player: {'rating': 915, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687788915
#   - White player: {'rating': 866, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/yorhatau', 'username': 'yorhatau', 'uuid': 'e4fe459c-eebc-11ec-b5c5-7ba535513496'}
#   - Black player: {'rating': 922, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687789101
#   - White player: {'rating': 900, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/kate0210', 'username': 'kate0210', 'uuid': '9c40bc1c-d3c3-11ed-986e-77912017fd21'}
#   - Black player: {'rating': 930, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687789467
#   - White player: {'rating': 908, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 904, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/peacefulwarrior83', 'username': 'peacefulwarrior83', 'uuid': '2eb8a0d6-393f-11eb-8575-bd951f280420'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687798629
#   - White player: {'rating': 900, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 912, 'result': 'win', '@id': 'https://api.chess.com/pub/player/adamw1979', 'username': 'adamw1979', 'uuid': '5f2a2e8a-0e31-11e1-8011-000000000000'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687798761
#   - White player: {'rating': 853, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mohamed_rushdy', 'username': 'Mohamed_Rushdy', 'uuid': '651626dc-6976-11eb-aa8b-4f48e6e7f9e0'}
#   - Black player: {'rating': 907, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687802472
#   - White player: {'rating': 871, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mdgraham7', 'username': 'mdgraham7', 'uuid': '260ed2f8-b5de-11e7-803a-000000000000'}
#   - Black player: {'rating': 898, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687802609
#   - White player: {'rating': 890, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 926, 'result': 'win', '@id': 'https://api.chess.com/pub/player/b00frommarioo', 'username': 'B00FromMarioo', 'uuid': '078e4782-944f-11ed-b4ac-87725dcd6d15'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687802730
#   - White player: {'rating': 898, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 882, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/corsostation2', 'username': 'corsostation2', 'uuid': '4078b632-1659-11e8-8024-000000000000'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687802940
#   - White player: {'rating': 905, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 841, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/the_mohammed_ali', 'username': 'The_Mohammed_Ali', 'uuid': '1178ca92-a364-11ec-9532-652b29aa2eb5'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687803078
#   - White player: {'rating': 912, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 858, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/kar_vy', 'username': 'kar_vy', 'uuid': '469293be-9536-11e9-9ec2-f7ee0873318e'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687803214
#   - White player: {'rating': 967, 'result': 'win', '@id': 'https://api.chess.com/pub/player/moiseschayo', 'username': 'MoisesChayo', 'uuid': 'c11e0de4-d74d-11e9-a641-59acd3e6638d'}
#   - Black player: {'rating': 905, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687803358
#   - White player: {'rating': 918, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/marat1234567891011', 'username': 'Marat1234567891011', 'uuid': 'd5833836-57c9-11ed-9aa7-ef61a71c2099'}
#   - Black player: {'rating': 913, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687803491
#   - White player: {'rating': 874, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/sonofdoctor', 'username': 'Sonofdoctor', 'uuid': '7db8d834-9d16-11e4-800c-000000000000'}
#   - Black player: {'rating': 920, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687803602
#   - White player: {'rating': 910, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 849, 'result': 'win', '@id': 'https://api.chess.com/pub/player/zyendup', 'username': 'Zyendup', 'uuid': '4a1b6894-4c36-11ec-ab25-a566f27cd4e8'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687803702
#   - White player: {'rating': 876, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/rcapistrano', 'username': 'rcapistrano', 'uuid': 'd326e98a-5cde-11eb-89e9-952fbeed7c48'}
#   - Black player: {'rating': 917, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687803832
#   - White player: {'rating': 908, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 896, 'result': 'win', '@id': 'https://api.chess.com/pub/player/metaknight89', 'username': 'MetaKnight89', 'uuid': 'cb07c960-0425-11ec-8550-0391d0c758f2'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687804129
#   - White player: {'rating': 926, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/harryshone', 'username': 'harryshone', 'uuid': '620d09ea-9417-11ea-9336-d12102e8fab6'}
#   - Black player: {'rating': 917, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687804264
#   - White player: {'rating': 910, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 964, 'result': 'win', '@id': 'https://api.chess.com/pub/player/grock777', 'username': 'Grock777', 'uuid': 'a37a930a-3abf-11e9-b68e-7114d70b15e3'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687804403
#   - White player: {'rating': 902, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 914, 'result': 'win', '@id': 'https://api.chess.com/pub/player/svetamoscow', 'username': 'svetamoscow', 'uuid': '85e51248-ba6f-11eb-a939-b33c496bee43'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687804528
#   - White player: {'rating': 910, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 881, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/dnbhattacharya', 'username': 'dnbhattacharya', 'uuid': 'e1f7727e-a478-11e4-8056-000000000000'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687804720
#   - White player: {'rating': 956, 'result': 'win', '@id': 'https://api.chess.com/pub/player/jar3d0', 'username': 'Jar3d0', 'uuid': '99b56122-7776-11ed-8c76-59cada1b13ec'}
#   - Black player: {'rating': 903, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687804855
#   - White player: {'rating': 896, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 936, 'result': 'win', '@id': 'https://api.chess.com/pub/player/falcon0182', 'username': 'falcon0182', 'uuid': '6bc3a5c0-9828-11e4-804e-000000000000'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687804993
#   - White player: {'rating': 884, 'result': 'win', '@id': 'https://api.chess.com/pub/player/austinm24', 'username': 'AustinM24', 'uuid': 'c4a8c4c4-56f2-11eb-9480-35b8d712edf7'}
#   - Black player: {'rating': 888, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687805145
#   - White player: {'rating': 896, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 891, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/suavy21', 'username': 'Suavy21', 'uuid': 'dd12d5f8-3c73-11ea-a99d-2befa6926746'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687805294
#   - White player: {'rating': 887, 'result': 'win', '@id': 'https://api.chess.com/pub/player/fordprefect404', 'username': 'FordPrefect404', 'uuid': 'b7f787b4-50ef-11eb-9690-21ceb4a3eb4c'}
#   - Black player: {'rating': 888, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687805369
#   - White player: {'rating': 877, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/runobot', 'username': 'Runobot', 'uuid': '05db4876-0e96-11ec-bff9-8db86ae17633'}
#   - Black player: {'rating': 896, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687805510
#   - White player: {'rating': 888, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 884, 'result': 'win', '@id': 'https://api.chess.com/pub/player/imranalexander', 'username': 'ImranAlexander', 'uuid': '22f2fac8-3c8f-11eb-9ce3-4d96f9ae1e4b'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687805650
#   - White player: {'rating': 898, 'result': 'win', '@id': 'https://api.chess.com/pub/player/loradras', 'username': 'Loradras', 'uuid': 'f7a86f3e-3409-11eb-8046-13f20c4535fa'}
#   - Black player: {'rating': 880, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687805772
#   - White player: {'rating': 872, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 904, 'result': 'win', '@id': 'https://api.chess.com/pub/player/polco-0', 'username': 'Polco-0', 'uuid': '8b7b4d90-ce65-11ea-9670-5b9a6eab0ca1'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687948839
#   - White player: {'rating': 881, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 905, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/theryzo', 'username': 'TheRyzo', 'uuid': '8a368954-355d-11eb-a171-0d7876ad8885'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687948969
#   - White player: {'rating': 889, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 860, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/sk319', 'username': 'SK319', 'uuid': 'cb67dcca-7dfc-11e5-805a-000000000000'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687949109
#   - White player: {'rating': 858, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/waterbear', 'username': 'waterbear', 'uuid': '5a1e83cc-6543-11dd-8063-000000000000'}
#   - Black player: {'rating': 896, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687961247
#   - White player: {'rating': 887, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 867, 'result': 'win', '@id': 'https://api.chess.com/pub/player/tikky69', 'username': 'tikky69', 'uuid': '6d30d738-d050-11e9-8473-3b3c32ae9a4c'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687961387
#   - White player: {'rating': 873, 'result': 'win', '@id': 'https://api.chess.com/pub/player/muezza257', 'username': 'muezza257', 'uuid': '3bd63f74-4a11-11ec-b71c-9bda988bd815'}
#   - Black player: {'rating': 878, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687961509
#   - White player: {'rating': 926, 'result': 'win', '@id': 'https://api.chess.com/pub/player/murga001', 'username': 'Murga001', 'uuid': '84bea344-96d1-11ed-9f0d-1726570e7cc3'}
#   - Black player: {'rating': 871, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687961541
#   - White player: {'rating': 829, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/nadidou71', 'username': 'nadidou71', 'uuid': '46fa6608-843e-11eb-95f5-adec132118b8'}
#   - Black player: {'rating': 878, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687961670
#   - White player: {'rating': 886, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 872, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/azhandy', 'username': 'Azhandy', 'uuid': 'e5d91edc-8717-11eb-8d60-950bb94fee04'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687961814
#   - White player: {'rating': 893, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/chris_s_m', 'username': 'chris_s_m', 'uuid': '0877a6f4-45cc-11e5-8052-000000000000'}
#   - Black player: {'rating': 894, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687961944
#   - White player: {'rating': 921, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/afatathtoad', 'username': 'afatathtoad', 'uuid': '815786c4-4813-11ed-a588-1d5f6fbc949b'}
#   - Black player: {'rating': 903, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687962027
#   - White player: {'rating': 894, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 868, 'result': 'win', '@id': 'https://api.chess.com/pub/player/ratagin', 'username': 'Ratagin', 'uuid': '98f77612-508b-11eb-a709-0574bf7d77bb'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687962176
#   - White player: {'rating': 886, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 909, 'result': 'win', '@id': 'https://api.chess.com/pub/player/rinatfayzullin', 'username': 'RinatFayzullin', 'uuid': 'fb2be1da-4142-11ec-91e9-0d3566cbb8d1'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687962330
#   - White player: {'rating': 887, 'result': 'stalemate', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 918, 'result': 'stalemate', '@id': 'https://api.chess.com/pub/player/xploxiv3', 'username': 'Xploxiv3', 'uuid': '32285a38-6fe6-11ed-8ef1-c9437384f1a9'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687962469
#   - White player: {'rating': 899, 'result': 'win', '@id': 'https://api.chess.com/pub/player/gmlb', 'username': 'GMLB', 'uuid': '5e5ca376-8383-11eb-ad6a-b742cb7a71ab'}
#   - Black player: {'rating': 879, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687962625
#   - White player: {'rating': 886, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 842, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/pavelse', 'username': 'pavelse', 'uuid': 'd750f054-2e69-11ea-a539-bd1537a0a050'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687962749
#   - White player: {'rating': 843, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/pattison77', 'username': 'Pattison77', 'uuid': '5836c306-2f37-11ea-80cc-e7a26fa36925'}
#   - Black player: {'rating': 893, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687962875
#   - White player: {'rating': 884, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 870, 'result': 'win', '@id': 'https://api.chess.com/pub/player/theblunderkingg', 'username': 'THEBLUNDERKINGG', 'uuid': 'c8c2487a-b708-11eb-8473-45cc71cb3cd6'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687962976
#   - White player: {'rating': 876, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/halabyeh2', 'username': 'halabyeh2', 'uuid': '27db3440-9a9f-11ed-b403-d58a5dcd3d76'}
#   - Black player: {'rating': 892, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687963103
#   - White player: {'rating': 885, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 934, 'result': 'win', '@id': 'https://api.chess.com/pub/player/edumaister', 'username': 'edumaister', 'uuid': 'ab71e61c-dd13-11e3-8000-000000000000'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687963239
#   - White player: {'rating': 936, 'result': 'win', '@id': 'https://api.chess.com/pub/player/rararaspootis', 'username': 'RaRaRaspootis', 'uuid': 'cd2700a8-eb39-11eb-b232-25bfff7b293f'}
#   - Black player: {'rating': 878, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687963339
#   - White player: {'rating': 908, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/lkeb', 'username': 'lkeb', 'uuid': '836c5d4c-9037-11de-801b-000000000000'}
#   - Black player: {'rating': 887, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687963469
#   - White player: {'rating': 894, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 838, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/qqeptam', 'username': 'QQeptaM', 'uuid': '0049964c-c774-11eb-9d82-23d23dc2a218'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687963616
#   - White player: {'rating': 863, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/karacoban', 'username': 'karacoban', 'uuid': '1cf49fbc-182f-11ea-8f8c-31f5945a6485'}
#   - Black player: {'rating': 901, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1687963762
#   - White player: {'rating': 921, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 892, 'result': 'win', '@id': 'https://api.chess.com/pub/player/cacasypedos', 'username': 'CacasYPedos', 'uuid': 'd1d73832-4c88-11ed-a5c6-23d6786641c1'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1687964182
#   - White player: {'rating': 914, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
# ...
#   - Black player: {'rating': 925, 'result': 'insufficient', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1740130478
#   - White player: {'rating': 928, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mk5s', 'username': 'Mk5s', 'uuid': 'd8db0c7c-97ac-11eb-bb6a-9b44fe597d54'}
#   - Black player: {'rating': 933, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1740134199
#   - White player: {'rating': 941, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 938, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/purwokerto1', 'username': 'purwokerto1', 'uuid': '5ac6c9c0-6857-11ed-b5a7-5de61374f10f'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1740134493
#   - White player: {'rating': 933, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 940, 'result': 'win', '@id': 'https://api.chess.com/pub/player/csleenhardt', 'username': 'CSLeenhardt', 'uuid': '50969b40-49de-11eb-ade2-f1c587b5f508'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1740135847
#   - White player: {'rating': 936, 'result': 'win', '@id': 'https://api.chess.com/pub/player/kopigorat', 'username': 'kopigorat', 'uuid': 'ca9ba62e-7a28-11ee-992f-13ddf804c9b3'}
#   - Black player: {'rating': 925, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1740136245
#   - White player: {'rating': 936, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/iyerkartik', 'username': 'iyerkartik', 'uuid': '1550efbc-f016-11ea-82e8-e957c3cb78fe'}
#   - Black player: {'rating': 933, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1740136448
#   - White player: {'rating': 925, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 944, 'result': 'win', '@id': 'https://api.chess.com/pub/player/iyerkartik', 'username': 'iyerkartik', 'uuid': '1550efbc-f016-11ea-82e8-e957c3cb78fe'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1740136745
#   - White player: {'rating': 932, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 879, 'result': 'abandoned', '@id': 'https://api.chess.com/pub/player/emielchess1', 'username': 'Emielchess1', 'uuid': '2960abbe-f413-11ee-a601-a9dad04aa15c'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1740136919
#   - White player: {'rating': 905, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/adityakd963', 'username': 'adityakd963', 'uuid': '6db2d85a-14da-11ee-bf47-4581556319ee'}
#   - Black player: {'rating': 940, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1740137046
#   - White player: {'rating': 950, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 1039, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/the1attacktitan', 'username': 'The1Attacktitan', 'uuid': 'e5bb9c7e-4a81-11ee-be14-3150c42de974'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1740140950
#   - White player: {'rating': 819, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/cs_pistol', 'username': 'cs_pistol', 'uuid': 'ad173da6-cfbf-11ee-a811-5f5f29db21b2'}
#   - Black player: {'rating': 959, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1740148139
#   - White player: {'rating': 869, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/papaw_azil', 'username': 'papaw_azil', 'uuid': 'ca4c3a1c-2a05-11ee-a6a1-2123da4974e5'}
#   - Black player: {'rating': 965, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1740148426
#   - White player: {'rating': 1151, 'result': 'abandoned', '@id': 'https://api.chess.com/pub/player/hakanpro123', 'username': 'hakanpro123', 'uuid': '13296de6-2e41-11ef-8bea-319257501eda'}
#   - Black player: {'rating': 977, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1740148693
#   - White player: {'rating': 978, 'result': 'timevsinsufficient', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 999, 'result': 'timevsinsufficient', '@id': 'https://api.chess.com/pub/player/trueskin', 'username': 'trueskin', 'uuid': '742539d2-ebb4-11ef-8899-fdc2c0849df7'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1740149202
#   - White player: {'rating': 877, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/deusimarchess', 'username': 'Deusimarchess', 'uuid': '8bf06330-3629-11ee-aec5-05a6a247c554'}
#   - Black player: {'rating': 984, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1740149434
#   - White player: {'rating': 995, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 1094, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/elmambero', 'username': 'ElMambero', 'uuid': 'b3bbd852-667b-11eb-8602-497adc252db5'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1740149728
#   - White player: {'rating': 1006, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 1141, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/buenavista20', 'username': 'buenavista20', 'uuid': '8e5bc036-d4db-11ef-b03a-b39d0ed529f6'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1740150402
#   - White player: {'rating': 213, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/quirkymaven', 'username': 'QuirkyMaven', 'uuid': '7ed9e876-b56a-11ef-9630-114865c24f4c'}
#   - Black player: {'rating': 1242, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1740247538
#   - White player: {'rating': 213, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/quirkymaven', 'username': 'QuirkyMaven', 'uuid': '7ed9e876-b56a-11ef-9630-114865c24f4c'}
#   - Black player: {'rating': 1242, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1740248776
#   - White player: {'rating': 1242, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 213, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/quirkymaven', 'username': 'QuirkyMaven', 'uuid': '7ed9e876-b56a-11ef-9630-114865c24f4c'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1740249552
#   - White player: {'rating': 213, 'result': 'win', '@id': 'https://api.chess.com/pub/player/quirkymaven', 'username': 'QuirkyMaven', 'uuid': '7ed9e876-b56a-11ef-9630-114865c24f4c'}
#   - Black player: {'rating': 1242, 'result': 'timeout', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1740250568
#   - White player: {'rating': 1242, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 1436, 'result': 'win', '@id': 'https://api.chess.com/pub/player/rraeeeeeeee', 'username': 'rraeeeeeeee', 'uuid': '85c910e0-d9d1-11ef-aca2-4fab530cd59c'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1740754817
#   - Extracted timing data from 176 games
#   - In this file: Wins: 88, Losses: 88, Other: 0
# Processing file: 2025-03.json
#   - Found 4 games in the file
#   - First game has pgn: True, has time_control: True
#   - Available fields in first game: ['url', 'pgn', 'time_control', 'end_time', 'rated', 'tcn', 'uuid', 'initial_setup', 'fen', 'time_class', 'rules', 'white', 'black', 'eco']
#   - White player: {'rating': 192, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/zikinep', 'username': 'Zikinep', 'uuid': 'e864bbac-b3e1-11ef-8426-8588ed3bce17'}
#   - Black player: {'rating': 1242, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - End time: 1741980201
#   - PGN sample: [Event "Live Chess"]
# [Site "Chess.com"]
# [Date "2025.03.14"]
# [Round "-"]
# [White "Zikinep"]
# [Black "Mr...
#
# Examining game 1:
#   - White player: {'rating': 192, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/zikinep', 'username': 'Zikinep', 'uuid': 'e864bbac-b3e1-11ef-8426-8588ed3bce17'}
#   - Black player: {'rating': 1242, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1741980201
#   - Game 1 result: win
#
# Examining game 2:
#   - White player: {'rating': 1242, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Black player: {'rating': 192, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/zikinep', 'username': 'Zikinep', 'uuid': 'e864bbac-b3e1-11ef-8426-8588ed3bce17'}
#   - Found MrEKO0 as white player
#   - Game ended at: 1741980260
#   - Game 2 result: win
#
# Examining game 3:
#   - White player: {'rating': 192, 'result': 'checkmated', '@id': 'https://api.chess.com/pub/player/zikinep', 'username': 'Zikinep', 'uuid': 'e864bbac-b3e1-11ef-8426-8588ed3bce17'}
#   - Black player: {'rating': 1242, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1741981424
#   - Game 3 result: win
#   - White player: {'rating': 192, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/zikinep', 'username': 'Zikinep', 'uuid': 'e864bbac-b3e1-11ef-8426-8588ed3bce17'}
#   - Black player: {'rating': 1242, 'result': 'win', '@id': 'https://api.chess.com/pub/player/mreko0', 'username': 'MrEKO0', 'uuid': '8008d55a-a521-11ed-adc8-f9403c3e5715'}
#   - Found MrEKO0 as black player
#   - Game ended at: 1741981553
#   - Extracted timing data from 4 games
#   - In this file: Wins: 4, Losses: 0, Other: 0
# Processing file: 2025-04.json
#   - Found 0 games in the file
#   - Extracted timing data from 0 games
#   - In this file: Wins: 0, Losses: 0, Other: 0
#
# SUMMARY:
# Total games with timing data: 2515
# Games won: 1349
# Games lost: 1166
# Games drawn/indeterminate: 0
#
# Move data points:
#   - All games - win: 39244 moves
#   - All games - loss: 39772 moves
#   - Blitz games - win: 18165 moves
#   - Blitz games - loss: 19754 moves
#   - Bullet games - win: 19392 moves
#   - Bullet games - loss: 18704 moves
#   - Rapid games - win: 1545 moves
#   - Rapid games - loss: 1307 moves
#   - Daily games - win: 142 moves
#   - Daily games - loss: 7 moves
# Plot saved as all_win.png
# Generated plot for All Games - Win with 39244 move data points
# Plot saved as all_loss.png
# Generated plot for All Games - Loss with 39772 move data points
# Plot saved as blitz_win.png
# Generated plot for Blitz Games - Win with 18165 move data points
# Plot saved as blitz_loss.png
# Generated plot for Blitz Games - Loss with 19754 move data points
# Plot saved as bullet_win.png
# Generated plot for Bullet Games - Win with 19392 move data points
# Plot saved as bullet_loss.png
# Generated plot for Bullet Games - Loss with 18704 move data points
# Plot saved as rapid_win.png
# Generated plot for Rapid Games - Win with 1545 move data points
# Plot saved as rapid_loss.png
# Generated plot for Rapid Games - Loss with 1307 move data points
# Plot saved as daily_win.png
# Generated plot for Daily Games - Win with 142 move data points
# Plot saved as daily_loss.png
# Generated plot for Daily Games - Loss with 7 move data points
# Wins plot saved as all_wins.png
# Losses plot saved as all_losses.png
# Wins plot saved as blitz_wins.png
# Losses plot saved as blitz_losses.png
# Wins plot saved as bullet_wins.png
# Losses plot saved as bullet_losses.png
# Wins plot saved as rapid_wins.png
# Losses plot saved as rapid_losses.png
# Wins plot saved as daily_wins.png
# Losses plot saved as daily_losses.png
# Histogram saved as all_time_histogram.png
# Box plot saved as all_time_boxplot.png
# <ipython-input-9-ce6b8b8f90d8>:35: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(box_data, labels=['Wins', 'Losses'], patch_artist=True,
# Violin plot saved as all_time_violin.png
# Heatmap saved as all_move_heatmap.png
# Histogram saved as blitz_time_histogram.png
# Box plot saved as blitz_time_boxplot.png
# <ipython-input-9-ce6b8b8f90d8>:35: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(box_data, labels=['Wins', 'Losses'], patch_artist=True,
# Violin plot saved as blitz_time_violin.png
# Heatmap saved as blitz_move_heatmap.png
# Histogram saved as bullet_time_histogram.png
# Box plot saved as bullet_time_boxplot.png
# <ipython-input-9-ce6b8b8f90d8>:35: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(box_data, labels=['Wins', 'Losses'], patch_artist=True,
# Violin plot saved as bullet_time_violin.png
# Heatmap saved as bullet_move_heatmap.png
# Histogram saved as rapid_time_histogram.png
# Box plot saved as rapid_time_boxplot.png
# <ipython-input-9-ce6b8b8f90d8>:35: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(box_data, labels=['Wins', 'Losses'], patch_artist=True,
# Violin plot saved as rapid_time_violin.png
# Heatmap saved as rapid_move_heatmap.png
# Histogram saved as daily_time_histogram.png
# Box plot saved as daily_time_boxplot.png
# <ipython-input-9-ce6b8b8f90d8>:35: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(box_data, labels=['Wins', 'Losses'], patch_artist=True,
# Violin plot saved as daily_time_violin.png
# Heatmap saved as daily_move_heatmap.png

# %% [markdown]
# Once the execution of the script is complete, the EDA plots/graphs will be saved to the same directory as this script.
